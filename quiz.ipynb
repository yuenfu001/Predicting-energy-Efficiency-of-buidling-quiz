# %%
# Q1

# %%
#L2 regularization is equivalent to impsing a Gaussian prior

# %%
# Q2

# %%
#Cross validation is gauranteed to prevent overfitting

# %%
# in the different terms of the bias-variance tradeoff, which of the following is substantially more harmful to test error than the training error?
#Answer: Variance

# %%
# Which of the following is ture about outliers in Linear Regression?
#Answer : Linear regression is sensitve to outliers

# %%
# Homw many coefficients d oyou need to estimate a simple linear regression model(One independent variable)
# Answer : 2

# %%
# Ridge regression :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model as LM
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
LM = LinearRegression()
MMS = MinMaxScaler()
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv")
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4       RH_4  \
# ...

# %%
pd.set_option("display.max_columns", None)
#pd.set_option("display.max_rows", None)

# %%
df.tail()
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3    T4       RH_4     T5  \
# 19730  25.890000  42.025714  27.200000  41.163333  24.7  45.590000  23.20
# 19731  25.754000  42.080000  27.133333  41.223333  24.7  45.590000  23.23
# 19732  25.628571  42.768571  27.050000  41.690000  24.7  45.730000  23.23
# 19733  25.414000  43.036000  26.890000  41.290000  24.7  45.790000  23.20
# 19734  25.264286  42.971429  26.823333  41.156667  24.7  45.963333  23.20
#
#             RH_5         T6  RH_6         T7       RH_7       T8      RH_8  \
# ...

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
simple_linear_reg_df = df[["T2","T6"]].sample(15, random_state =42)
simple_linear_reg_df1 = df[["T2","Appliances"]].sample(15, random_state =42)
simple_linear_reg_df2 = df[["T6","Appliances"]].sample(15, random_state =42)

# %%
sns.regplot(x="T2", y="T6", data=simple_linear_reg_df)
# Out:
# <AxesSubplot:xlabel='T2', ylabel='T6'>

# %%
sns.regplot(x="T2", y="Appliances", data=simple_linear_reg_df1)
# Out:
# <AxesSubplot:xlabel='T2', ylabel='Appliances'>

# %%
sns.regplot(x="T6", y="Appliances", data=simple_linear_reg_df2)
# Out:
# <AxesSubplot:xlabel='T6', ylabel='Appliances'>

# %%
#df_new = df.rename(columns=column_names)

# %%
df = df.drop(columns=["date","lights"])
df
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5       RH_5         T6  \
# ...

# %%
normalised_df = pd.DataFrame(MMS.fit_transform(df), columns = df.columns)
normalised_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
feature_df = normalised_df.drop(columns="Appliances")
feature_df
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0      0.327350  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1      0.327350  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2      0.327350  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3      0.327350  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4      0.327350  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374  0.864865
# 19731  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178  0.864865
# 19732  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988  0.864865
# 19733  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294  0.864865
# 19734  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062  0.864865
#
# ...

# %%
target_var = normalised_df["Appliances"]
target_var
# Out:
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
#            ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
# Name: Appliances, Length: 19735, dtype: float64

# %%
x_train, x_test,y_train, y_test = tts(feature_df["T2"].values.reshape(-1,1),feature_df["T6"], train_size= 0.7 , random_state=42)

# %%
model = LM.fit(x_train, y_train)
model
# Out:
# LinearRegression()

# %%
x_test
# Out:
# array([[0.12066877],
#        [0.37727163],
#        [0.11146111],
#        ...,
#        [0.18899927],
#        [0.33438333],
#        [0.21322995]])

# %%
y_test
# Out:
# 8980     0.211427
# 2754     0.250182
# 9132     0.168777
# 14359    0.501383
# 8875     0.155193
#            ...
# 831      0.179450
# 10993    0.428613
# 11761    0.455974
# 12364    0.560638
# 11863    0.540387
# Name: T6, Length: 5921, dtype: float64

# %%
predicted_values = LM.predict(x_test)
predicted_values
# Out:
# array([0.23928945, 0.46794238, 0.23108472, ..., 0.3001772 , 0.4297256 ,
#        0.3217686 ])

# %%
round(LM.score(x_test,y_test),3)
# Out:
# 0.643

# %%
MAE = mean_absolute_error(y_test, predicted_values)
round(MAE, 2)
# Out:
# 0.08

# %%
SS = y_test - predicted_values
RSS = np.sum(np.square(SS))
round(RSS,2)
# Out:
# 66.12

# %%
RMSE = np.sqrt(mean_squared_error(y_test, predicted_values))
round(RMSE, 3)
# Out:
# 0.106

# %%
R2_value = r2_score(y_test, predicted_values)
round(R2_value,3)
# Out:
# 0.643

# %%
from sklearn import metrics
coefficent = metrics.r2_score(y_test, predicted_values)
round(coefficent,2)
# Out:
# 0.64

# %%
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.4)

# %%
lasso_reg = Lasso(alpha=0.4)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.4)

# %%
model
# Out:
# LinearRegression()

# %%
predicted_values
# Out:
# array([0.23928945, 0.46794238, 0.23108472, ..., 0.3001772 , 0.4297256 ,
#        0.3217686 ])

# %%
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
lasso_reg = Ridge(alpha=.001)
lasso_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ["Features", col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
linear_model_weights = get_weights_df(model, x_train, "Linear_Model_Weight")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-679-f01bb4c89ab8> in <module>
# ----> 1 linear_model_weights = get_weights_df(model, x_train, "Linear_Model_Weight")
#
# <ipython-input-677-870dc16d5521> in get_weights_df(model, feat, col_name)
#       1 def get_weights_df(model, feat, col_name):
# ----> 2     weights = pd.Series(model.coef_, feat.columns).sort_values()
#       3     weights_df = pd.DataFrame(weights).reset_index()
#       4     weights_df.columns = ["Features", col_name]
#       5     weights_df[col_name].round(3)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
